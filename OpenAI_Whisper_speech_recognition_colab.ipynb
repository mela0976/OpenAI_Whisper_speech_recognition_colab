# %% [markdown]
# <a href="https://colab.research.google.com/github/mela0976/OpenAI_Whisper_speech_recognition_colab/blob/main/OpenAI_Whisper_speech_recognition_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title OpenAI Whisper 語音辨識並輸出字幕檔案程式

#@markdown <b>設定底下的自訂參數後，就可以按左側的執行鈕</b>

#@markdown <b>聲音檔的來源</b>，可以是網址(Youtube影片、撥放清單)，或是上載後的影片、聲音檔檔案名稱。<br />有多個可以放入 .txt 檔案中(例: list.txt)，一行一個網址或是檔案路徑。
url = "recordings.m4a" #@param {type:"string"}
#@markdown <b>語音的語言代碼</b>
lang = 'Chinese' #@param ["Chinese", "English", "Japanese", "Korean", "自動判斷"]
#@markdown <b>輸出為哪一種格式</b>（.srt:字幕檔、.txt:純文字檔）
outputFormat = 'txt' #@param ['srt', 'txt']
#@markdown <b>輸出到哪個資料夾</b>(空白表示使用預設值)
output_path = '' #@param {type:"string"}
#@markdown <b>是否覆蓋已存在的辨識結果</b>(沒勾選會跳過已辨識過的)
overwrite_enable = True #@param { type: 'boolean' }
#@markdown <b>使用哪一種辨識模型</b>（small:快/普通，medium:慢/精準, large:很慢/最精準[建議使用]）
modelType = 'large' #@param ["small" , "medium","large"]
#@markdown <b>是否全部辨識完成，立即下載字幕檔</b>
start_downloading_immediately = True #@param { type: 'boolean' }
#@markdown <b>是否即時顯示語音辨識結果</b>
verbose = True #@param { type: 'boolean' }
#markdown <b>是否使用 yt-dlp 下載 Youtube 聲音檔</b><br />(如果較長的聲音檔下載發生問題時再勾選使用)
#YoutubeDL_enable = False #@param { type: 'boolean' }

#@markdown ---
#@markdown <center><p><font color="blue">以下為指令輸出內容</p></center>

# Install + Import + Config
try: import whisper
except:
  print('install whisper ...')
  # !pip install -qU git+https://github.com/openai/whisper.git

try: from pytubefix import YouTube
except :
  print('install pytubefix ...')
  # !pip install pytubefix

try: from slugify import slugify
except:
  print('install python-slugify ...')
  # !pip install -qqU python-slugify


import torch
import whisper
from whisper.utils import get_writer
from pytubefix import YouTube
import re
import os
import urllib.request
from slugify import slugify
import google

audioFile = 'source.mp3'
tempFolder = '.'
title = ''
textFileList = []

if re.sub('\s', '', output_path) == '' :
  #如果沒有輸入，就輸出到預設的暫存資料夾
  output_path = tempFolder
else :
  if os.path.exists(output_path) :
    if not os.path.isdir(output_path) :
      print(output_path + ' 不是資料夾哦! 改用預設值: '+tempFolder)
      output_path = tempFolder
  else :
    print('指定的輸出目錄 '+output_path+' 不存在, 改用預設值: '+tempFolder)
    output_path = tempFolder

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

def getYoutubeInfo(url):
  """
  使用 pytubefix 由 Youtbue 網址擷取影片的資訊
  """
  yt = YouTube(url)
  info_dict = yt.vid_info
  return info_dict

def getFilenameFromTitle(title) :
  """
  convert title to valid filename
  :param title: text to slugify
  """
  return slugify(title, allow_unicode=True, lowercase=False)

def getOutputTextFilename(filename) :
  fPath = os.path.relpath(output_path)
  return os.path.join(fPath, filename+'.'+outputFormat)

def isOutputTextFileExists(filename) :
  return os.path.exists(getOutputTextFilename(filename))

def removeAudioFile(filename) :
  if os.path.exists(filename) :
    os.remove(filename)

def convertNewLineFormat(filename) :
  if os.path.exists(filename) :
    f = open(filename, 'r+')
    data = f.read()
    data = re.sub('\r', '', data, re.MULTILINE) #remove all \r
    data = re.sub('\n', '\r\n', data, re.MULTILINE) #replace \n to \r\n
    f.seek(0)
    f.write(data)
    f.truncate()
    f.close()

def getAudioFromYoutube(url, output_path, outputFilename):
  """
  使用 pytubefix 由 Youtbue 網址下載影片的聲音並存檔
  :param url: Youtube 影片網址
  :param output_path: 儲存的資料夾名稱
  :param outputFilename: 聲音檔的檔名
  """
  #filename為去掉副檔名的路徑，以免變成 xxx.mp3.mp3
  filename = os.path.join(output_path, outputFilename)
  yt = YouTube(url)
  ys = yt.streams.get_audio_only()
  ys.download(filename=outputFilename)


def saveToFile(result, output_path, filename, fileType='srt') :
  """
  save whisper transcribe result to a file
  :param result: whisper transcribe result
  :param output_path: the folder to save result
  :param filename: the filename(without the extension) to save result
  :param fileType: the transcribe result format (thie extension of filename)
  """
  file_writer = get_writer(fileType, output_path) #whisper get_writer

  #可標定字的時間截記 word_timestamps 必須傳入 writer_args 參數
  writer_args = {'highlight_words': False, 'max_line_count': None, 'max_line_width': None}
  file_writer(result, filename, writer_args)

def transcribe(audioFilename, output_path, outputFilename, outputFormat) :
  """
  load whisper model and get transcribe result
  :param audioFilename: audio file to transcribe
  :param output_path: the folder to save result
  :param outputFilename: the filename(without the extension) to save result
  :param outputFormat: the transcribe result format (thie extension of filename)
  """

  model = whisper.load_model(modelType, device=DEVICE)
  if lang=="自動判斷" :
    print('auto detect language')
    result = model.transcribe(audioFilename, fp16=False, verbose=verbose)
  else :
    result = model.transcribe(audioFilename, fp16=False, verbose=verbose, language=lang)
  # save result to outputFormat file
  saveToFile(result, output_path, outputFilename, outputFormat)

def getAudioAndTranscribe(urlOrFile):
  filename = audioFile #語音檔檔名(辨識用的暫存檔，用固定的名稱較方便)
  # 分網址或是Colab儲存空間檔案處理
  if re.search('https\:\/\/', urlOrFile):
    isPlayList = False
    # Youtube 分播放清單跟單一影片處理
    if re.search('youtube\.|youtu\.', urlOrFile) :
      # 建立 Playlist 物件
      videoInfo = getYoutubeInfo(urlOrFile)

      # Youtube single video
      title = videoInfo['videoDetails']['title']
      outputFilename = getFilenameFromTitle(title) #用影片的標題當主檔名，但需將不適合的字置換或去除
      #如果設定辨識過的重新辨識(overwrite_enable), 或是輸出字幕檔不存在就呼叫whisper
      if not isOutputTextFileExists(outputFilename) or overwrite_enable :
        # delete the old audio file
        removeAudioFile(filename)
        print('>> 下載影音檔案中...')
        try: getAudioFromYoutube(urlOrFile, tempFolder, filename)
        except:
          print('>>>無法由網址下載影音')
      #將輸出的檔名列入結果清單中，方便後續壓縮、下載
      textFileList.append(getOutputTextFilename(outputFilename))
    else :
      print('請提供 YouTube 網址或檔案名稱')
  else :
    #Colab儲存空間檔案處理(非網址的影音檔)
    isPlayList = False
    title = os.path.splitext(os.path.basename(urlOrFile))[0] #去掉資料夾名稱及附檔名，只取主檔名
    outputFilename = getFilenameFromTitle(title) #結果輸出檔的主檔名
    filename = urlOrFile #辨識指定的影音檔
    if os.path.exists(filename) :
      #將輸出的檔名列入結果清單中，方便後續壓縮、下載
      textFileList.append(getOutputTextFilename(outputFilename))
      #如果字幕檔已存在，而且不可覆蓋，就故意將語音檔設為不存在的檔名，這樣就不會重新辨識
      if (not overwrite_enable) and isOutputTextFileExists(outputFilename) :
        filename = 'fakeFilename.fake'
  #辨識非播放清單的單一語音檔
  if not isPlayList :
    print('\n>> '+title)
    # 語音檔存在的話，就進行辨識
    # load whisper model and get transcribe result
    print('\n>> 準備進行語音辨識...\n')
    if os.path.exists(filename) :
      print('>>>Whisper 辨識中...\n')
      transcribe(filename, output_path, outputFilename, outputFormat)
    else :
      print('>>>找不到語音檔，請確定影音檔是否已準備好了\n')
  return title

#解析 .txt 檔案中的清單，一行行進行去抓音檔並進行辨識
def parseTxtFileAndTranscribe(txtFile) :
  if os.path.exists(txtFile) :
    file = open(txtFile, 'r')
    lines = file.readlines()
    file.close()
    for line in lines :
      line = re.sub('\r|\n', '', line, re.MULTILINE) #去掉所有換行字元
      getAudioAndTranscribe(line)
  else :
    print('找不到檔案: '+txtFile)

if (re.search('https\:\/\/', url) is None) and (not re.search('\.txt$', url, re.IGNORECASE) is None) :
  #解析 .txt 檔中的清單後，再進行辨識
  parseTxtFileAndTranscribe(url)
  title = os.path.splitext(os.path.basename(url))[0] #去掉資料夾名稱及附檔名，只取主檔名
else :
  #直接辨識 url 指定的網址或是檔案
  title = getAudioAndTranscribe(url)


if len(textFileList)>0 and start_downloading_immediately :
  print('download...')
  filenames_list = ''
  for textFile in textFileList :
    if os.path.exists(textFile) :
      convertNewLineFormat(textFile) # replace \n with \r\n (Windows format)
      if os.getcwd() != os.path.dirname(os.path.abspath(textFile)) :
        filename = os.path.basename(textFile)
        #copy textFile to current work directory
        ! cp {textFile} ./
      else :
        filename = textFile
      if filenames_list != '' :
        filenames_list = filenames_list+' '
      filenames_list = filenames_list+filename

  if len(textFileList)>1 :
    print('\n壓縮並下載辨識結果')
    outputFilename = slugify(title, allow_unicode=True, lowercase=False)+'-'+outputFormat+'.zip'
    ! zip {outputFilename} -D {filenames_list}
  else :
    print('\n下載辨識結果')
    outputFilename = filenames_list

  google.colab.files.download(outputFilename)
# Out:
# >> recordings
#
# >> 準備進行語音辨識...
#
# >>>Whisper 辨識中...
# 100%|█████████████████████████████████████| 2.88G/2.88G [01:06<00:00, 46.2MiB/s]
# [00:00.000 --> 00:02.000] 好
# [00:02.000 --> 00:04.000] 那所以因此就是
# [00:04.000 --> 00:05.000] 我們會想說
# [00:05.000 --> 00:07.000] 喔 那如果是這樣
# [00:07.000 --> 00:08.000] 我們應該
# [00:08.000 --> 00:11.000] 至少有一部分是像我們以前在
# [00:11.000 --> 00:13.000] 人工智慧學校所做的
# [00:13.000 --> 00:15.000] 我們那時候當年是教
# [00:15.000 --> 00:17.000] 經理人 教技術領袖
# [00:17.000 --> 00:20.000] 然後讓他們回到公司去
# [00:20.000 --> 00:21.000] 去培育 去發展
# [00:21.000 --> 00:24.000] 後來等到我來的時候就開始
# [00:24.000 --> 00:27.000] 培育類似像是高階主管
# [00:27.000 --> 00:28.000] 董事長 總經理
# [00:28.000 --> 00:29.000] 這種C level的人
# [00:29.000 --> 00:31.000] 所以也產生一些成效
# [00:31.000 --> 00:33.000] 例如說在去年
# [00:33.000 --> 00:34.000] 其中有一家做
# [00:34.000 --> 00:36.000] 預防混凝土的公司
# [00:36.000 --> 00:38.000] 得到了哈佛商業評論的
# [00:38.000 --> 00:39.000] 作業轉型頂格獎
# [00:39.000 --> 00:43.000] 那是我們從那個時候培養出來的
# [00:43.000 --> 00:46.000] 那後來我們又有新的想法就是
# [00:46.000 --> 00:51.000] 如果我們可以把現在的AI的技術
# [00:51.000 --> 00:54.000] 加上一些產業的know-how
# [00:54.000 --> 00:58.000] 然後讓科大的老師
# [00:58.000 --> 00:59.000] in
# [00:59.000 --> 01:02.000] ABLE們之後能夠去幫忙
# [01:02.000 --> 01:04.000] 直接幫忙
# [01:04.000 --> 01:08.000] 然後甚至跟業者co-work
# [01:08.000 --> 01:12.000] 把適合他們的東西做出來
# [01:12.000 --> 01:14.000] 適合他們用的
# [01:14.000 --> 01:16.000] 直接就這樣比較快
# [01:16.000 --> 01:19.000] 那因為我也知道很多老師是有
# [01:19.000 --> 01:22.000] 跟在地的SIR業者合作
# [01:22.000 --> 01:26.000] 那我們認為這樣子的模式
# [01:26.000 --> 01:28.000] 應該有機會推動中小微
# [01:28.000 --> 01:31.000] 以及自產業的發展
# [01:31.000 --> 01:34.000] 那這個我們當然是也希望說
# [01:34.000 --> 01:36.000] 能夠第一個就教育
# [01:36.000 --> 01:37.000] 就是校長這邊
# [01:37.000 --> 01:39.000] 然後另外就是說
# [01:39.000 --> 01:40.000] 也想要知道說
# [01:40.000 --> 01:42.000] 因為南台在
# [01:42.000 --> 01:45.000] 在南部這邊很有影響力
# [01:45.000 --> 01:47.000] 那我們會很希望
# [01:47.000 --> 01:49.000] 像那個什麼
# [01:49.000 --> 01:50.000] 化工系這邊有一位教授
# [01:50.000 --> 01:51.000] 我也跟他很熟
# [01:51.000 --> 01:53.000] 他也是清大的
# [01:53.000 --> 01:54.000] 那個是
# [01:54.000 --> 01:55.000] 對
# [01:55.000 --> 01:56.000] 對
# [01:56.000 --> 01:57.000] 他也是清華校長
# [01:57.000 --> 01:58.000] 他也是清華校長
# [01:58.000 --> 01:59.000] 對
# [01:59.000 --> 02:00.000] 他現在是系主任
# [02:00.000 --> 02:01.000] 他系主任喔
# [02:01.000 --> 02:02.000] 對
# [02:02.000 --> 02:03.000] 本來是
# [02:03.000 --> 02:04.000] 應該本來是
# [02:04.000 --> 02:05.000] 副研發長
# [02:05.000 --> 02:06.000] 對對對
# [02:06.000 --> 02:07.000] 我認識他是副研發長
# [02:07.000 --> 02:08.000] 對
# [02:08.000 --> 02:11.000] 因為系主任有異動
# [02:11.000 --> 02:15.000] 所以他覺得他來擔任系主任
# [02:15.000 --> 02:17.000] 所以他現在是我們化工
# [02:17.000 --> 02:20.000] 化工材料的系主任
# [02:20.000 --> 02:21.000] 對
# [02:21.000 --> 02:22.000] OK
# [02:22.000 --> 02:23.000] 太好了
# [02:23.000 --> 02:25.000] 對那因為我跟他蠻熟的
# [02:25.000 --> 02:26.000] 對
# [02:26.000 --> 02:28.000] 他說他也在南部校友會啦
# [02:28.000 --> 02:30.000] 但是我之前沒有看過他
# [02:30.000 --> 02:31.000] 是是是
# [02:31.000 --> 02:32.000] 對
# [02:32.000 --> 02:33.000] 昨天南部校友會
# [02:33.000 --> 02:34.000] 才在這邊辦
# [02:34.000 --> 02:35.000] 有有有
# [02:35.000 --> 02:36.000] 一個論壇
# [02:36.000 --> 02:37.000] 對對對我有看到
# [02:37.000 --> 02:38.000] 前天啦
# [02:38.000 --> 02:39.000] 前天
# [02:39.000 --> 02:40.000] 陳文村校長
# [02:40.000 --> 02:41.000] 對對對
# [02:41.000 --> 02:42.000] 那個這邊的
# [02:42.000 --> 02:44.000] 簽書會
# [02:44.000 --> 02:47.000] 然後就辦一個半導體AI相關的論壇
# [02:47.000 --> 02:48.000] 是是
# [02:48.000 --> 02:49.000] 蠻熱鬧的
# [02:49.000 --> 02:50.000] 是
# [02:50.000 --> 02:52.000] 所以當然就是
# [02:52.000 --> 02:55.000] 我可能不完全會按照那個所謂訪剛啦
# [02:55.000 --> 02:56.000] 是是沒關係
# [02:56.000 --> 02:57.000] 那我們就聊天
# [02:57.000 --> 02:58.000] 對就聊天
# [02:58.000 --> 02:59.000] 就聊天
# [02:59.000 --> 03:00.000] 因為這個是我想要也先聽聽看說
# [03:00.000 --> 03:02.000] 因為我想校長大概也看過
# [03:02.000 --> 03:03.000] 是
# [03:03.000 --> 03:04.000] 這裡面的一些
# [03:04.000 --> 03:05.000] 對對對
# [03:05.000 --> 03:06.000] 內容
# [03:06.000 --> 03:07.000] 大概看了一下
# [03:07.000 --> 03:08.000] 但裡面有些想法跟指教
# [03:08.000 --> 03:09.000] 對呀就聊一聊這樣子
# [03:09.000 --> 03:10.000] 是是是
# [03:10.000 --> 03:11.000] 對對對
# [03:11.000 --> 03:12.000] 是
# [03:12.000 --> 03:13.000] 那我們就
# [03:13.000 --> 03:14.000] 我就一邊聊啦
# [03:14.000 --> 03:15.000] 是是
# [03:15.000 --> 03:16.000] 那我覺得說
# [03:16.000 --> 03:18.000] 如果南台這邊可以扮演一些
# [03:18.000 --> 03:19.000] 協助的角色
# [03:19.000 --> 03:20.000] 我們當然非常樂意
# [03:20.000 --> 03:21.000] 就剛剛你提到
# [03:21.000 --> 03:23.000] 因為在南部的科大
# [03:23.000 --> 03:24.000] 跟我們家南部的科大
# [03:24.000 --> 03:25.000] 跟我們家南部的這些
# [03:25.000 --> 03:26.000] 不管傳統產業啦
# [03:26.000 --> 03:28.000] 或者因為這邊有南科嘛
# [03:28.000 --> 03:30.000] 這些高科之業
# [03:30.000 --> 03:35.000] 其實連結還算互動也都還蠻不錯的
# [03:35.000 --> 03:36.000] 落地啦
# [03:36.000 --> 03:39.000] 就比較接近那個接地氣可能強一點
# [03:39.000 --> 03:42.000] 那我覺得說南台如果再
# [03:42.000 --> 03:45.000] 現在政府在推大南方矽谷
# [03:45.000 --> 03:47.000] 強調百工百業
# [03:47.000 --> 03:50.000] 如果培養AI的人才的缺口也很大
# [03:50.000 --> 03:51.000] 是
# [03:51.000 --> 03:52.000] 只是在落地
# [03:52.000 --> 03:54.000] 可能南台科大的那個人
# [03:54.000 --> 03:55.000] 就近啦
# [03:55.000 --> 03:58.000] 可能這個可以做一些協助
# [03:58.000 --> 04:00.000] 所以我們是很樂意啦
# [04:00.000 --> 04:03.000] 看怎麼來搭配這樣子
# [04:03.000 --> 04:05.000] 我們預計是這樣
# [04:05.000 --> 04:06.000] 可能我們
# [04:06.000 --> 04:07.000] 我先也報告一下
# [04:07.000 --> 04:11.000] 我們最近的規劃跟行程
# [04:11.000 --> 04:13.000] 現在是四月底的嘛
# [04:13.000 --> 04:14.000] 四月底
# [04:14.000 --> 04:15.000] 我們預計在兩個月後
# [04:15.000 --> 04:17.000] 六月二十五號
# [04:17.000 --> 04:21.000] 會在成大那邊先弄一個
# [04:21.000 --> 04:23.000] AI乘以南方力量的論壇
# [04:23.000 --> 04:24.000] OK
# [04:24.000 --> 04:25.000] 好
# [04:25.000 --> 04:26.000] 那這個論壇呢
# [04:26.000 --> 04:28.000] 其實我們算是
# [04:28.000 --> 04:30.000] 我們應該是算
# [04:30.000 --> 04:32.000] 重兵出動啦
# [04:32.000 --> 04:33.000] 對
# [04:33.000 --> 04:35.000] 因為剛好就是說孔雲氏有回來
# [04:35.000 --> 04:38.000] 所以我會邀請孔雲氏當Kino
# [04:38.000 --> 04:39.000] 是
# [04:39.000 --> 04:40.000] 本來我們一直在商討
# [04:40.000 --> 04:41.000] 其實說到底要找誰
# [04:41.000 --> 04:42.000] 後來就說
# [04:42.000 --> 04:44.000] 欸啊竟然有寶在那裡
# [04:44.000 --> 04:46.000] 為什麼不直接請出來就好
# [04:46.000 --> 04:47.000] 他剛好回到台灣
# [04:47.000 --> 04:48.000] 他剛好
# [04:48.000 --> 04:50.000] 因為我們上禮拜開會嘛
# [04:50.000 --> 04:52.000] 線上開會才知道說
# [04:52.000 --> 04:54.000] 喔那這次會回來比較久
# [04:54.000 --> 04:55.000] 喔
# [04:55.000 --> 04:57.000] 因為他有時候也是來來去去的
# [04:57.000 --> 04:58.000] 對
# [04:58.000 --> 04:59.000] 他來來去去的話
# [04:59.000 --> 05:00.000] 你就很難抓他的事情
# [05:00.000 --> 05:01.000] 他有時候在交代
# [05:01.000 --> 05:02.000] 有時候在清大
# [05:02.000 --> 05:03.000] 有時候在
# [05:03.000 --> 05:04.000] 他有時候去藏根
# [05:04.000 --> 05:05.000] 有時候就
# [05:05.000 --> 05:06.000] 有時候可能回來台灣幾天
# [05:06.000 --> 05:07.000] 然後突然說
# [05:07.000 --> 05:09.000] 欸我要去新加坡
# [05:09.000 --> 05:11.000] 他說喔那就突然就飛出去了這樣
# [05:11.000 --> 05:12.000] 對
# [05:12.000 --> 05:13.000] 他那個比較
# [05:13.000 --> 05:15.000] 比較繁忙啊
# [05:15.000 --> 05:17.000] 八十幾歲
# [05:17.000 --> 05:18.000] 喔他已經有八十喔
# [05:18.000 --> 05:19.000] 八十幾歲
# [05:19.000 --> 05:20.000] 哇
# [05:20.000 --> 05:21.000] 對
# [05:21.000 --> 05:22.000] 所以就喔這八十幾歲還這麼
# [05:22.000 --> 05:23.000] 還這麼active喔
# [05:23.000 --> 05:24.000] 對啊
# [05:24.000 --> 05:25.000] 火力
# [05:25.000 --> 05:26.000] 火力十足
# [05:26.000 --> 05:27.000] 有時候都覺得
# [05:27.000 --> 05:28.000] 我們都覺得很累
# [05:28.000 --> 05:30.000] 怎麼還是這麼拚
# [05:30.000 --> 05:33.000] 然後我們會6月25號禮拜三
# [05:33.000 --> 05:36.000] 我會邀請校長來當來賓
# [05:36.000 --> 05:39.000] 然後我們會
# [05:39.000 --> 05:41.000] 當然就是我們這次是跟
# [05:41.000 --> 05:42.000] 那個叫什麼
# [05:42.000 --> 05:44.000] 成大的研發基金會
# [05:44.000 --> 05:46.000] 研究發展基金會合辦
# [05:46.000 --> 05:50.000] 所以會另外一個Kino會請的那個
# [05:50.000 --> 05:51.000] 蘇校長
# [05:51.000 --> 05:52.000] 蘇董事
# [05:52.000 --> 05:53.000] 對對對
# [05:53.000 --> 05:54.000] 陳蘇董事長
# [05:54.000 --> 05:55.000] 蘇校長
# [05:55.000 --> 05:57.000] 我都叫他蘇校長習慣了
# [05:57.000 --> 05:58.000] 蘇惠珍
# [05:58.000 --> 05:59.000] 對對對
# [05:59.000 --> 06:00.000] OKOK
# [06:00.000 --> 06:01.000] 然後
# [06:01.000 --> 06:02.000] 然後接下來
# [06:02.000 --> 06:03.000] 6月
# [06:03.000 --> 06:04.000] 對不起我看
# [06:04.000 --> 06:05.000] 我看6月25
# [06:05.000 --> 06:06.000] OK好
# [06:06.000 --> 06:07.000] 可以
# [06:07.000 --> 06:08.000] 我們會我們在正式的
# [06:08.000 --> 06:09.000] 正式的邀請會再給你
# [06:09.000 --> 06:10.000] 對對沒關係
# [06:10.000 --> 06:11.000] 我是先看我那天有沒有什麼重要的事
# [06:11.000 --> 06:12.000] 喔好
# [06:12.000 --> 06:15.000] 然後我們預計就會邀幾個
# [06:15.000 --> 06:17.000] 產業的就是
# [06:17.000 --> 06:20.000] 當然就是北部會邀什麼新漢的
# [06:20.000 --> 06:21.000] 新漢的董事長
# [06:21.000 --> 06:22.000] 然後
# [06:22.000 --> 06:24.000] 再來就是
# [06:24.000 --> 06:25.000] 嚴董
# [06:25.000 --> 06:26.000] 東海的嚴董
# [06:26.000 --> 06:27.000] 喔
# [06:27.000 --> 06:29.000] 然後可能漢翔的媽
# [06:29.000 --> 06:31.000] 媽總也是我們身家新大校友
# [06:31.000 --> 06:32.000] 喔
# [06:32.000 --> 06:33.000] 媽總是
# [06:33.000 --> 06:34.000] 我上禮拜五才跟他見面
# [06:34.000 --> 06:35.000] 是
# [06:35.000 --> 06:36.000] 媽總是
# [06:36.000 --> 06:37.000] 動機所的
# [06:37.000 --> 06:38.000] 動機所
# [06:38.000 --> 06:39.000] 對動機博
# [06:39.000 --> 06:40.000] 漢翔
# [06:40.000 --> 06:41.000] 對漢翔
# [06:41.000 --> 06:42.000] OK
# [06:42.000 --> 06:43.000] 對對對
# [06:43.000 --> 06:44.000] 然後另外就是
# [06:44.000 --> 06:46.000] 另外一個Track可能會跟
# [06:46.000 --> 06:48.000] 叫做長照
# [06:48.000 --> 06:49.000] 長照
# [06:49.000 --> 06:50.000] 照護相關
# [06:50.000 --> 06:51.000] 那我就請那個
# [06:51.000 --> 06:52.000] 那個
# [06:58.040 --> 06:59.000] 對
# [06:59.000 --> 07:01.000] 然後還有一些我們會再約一些
# [07:01.000 --> 07:02.000] 就是做
# [07:02.000 --> 07:04.000] 例如說快銷或者是做這個叫什麼
# [07:04.000 --> 07:05.000] 快銷或是
# [07:05.000 --> 07:06.000] 像技術加工的那些
# [07:06.000 --> 07:07.000] 喔不是
# [07:07.000 --> 07:08.000] 快銷
# [07:08.000 --> 07:09.000] 快速消費品
# [07:09.000 --> 07:10.000] 喔
# [07:10.000 --> 07:11.000] 或是說就是
# [07:11.000 --> 07:12.000] 就是一些比較民生的
# [07:12.000 --> 07:13.000] 喔民生方面的
# [07:13.000 --> 07:14.000] 對對
# [07:14.000 --> 07:15.000] 民生方面的
# [07:15.000 --> 07:16.000] 反正就我們會組成一個
# [07:16.000 --> 07:17.000] 做一個這樣的論壇
# [07:17.000 --> 07:18.000] 是
# [07:18.000 --> 07:19.000] 主要我們會希望
# [07:19.000 --> 07:20.000] 對
# [07:20.000 --> 07:21.000] 我們會有邀請
# [07:21.000 --> 07:22.000] 對
# [07:22.000 --> 07:23.000] 對
# [07:23.000 --> 07:24.000] 那簡單說就是我們
# [07:24.000 --> 07:26.000] 625會先有一個這個
# [07:26.000 --> 07:28.000] 然後我們可能到第三季
# [07:28.000 --> 07:30.000] 最慢到第四季的前面
# [07:30.000 --> 07:34.000] 我們就會舉辦我們剛剛所說的那個叫做
# [07:34.000 --> 07:37.000] 一般中文叫培力
# [07:37.000 --> 07:39.000] 但我們其實就是Channel Channer Program
# [07:39.000 --> 07:40.000] OK
# [07:40.000 --> 07:41.000] 好Channel Channer
# [07:41.000 --> 07:42.000] 因為這個Channel Channer Program
# [07:42.000 --> 07:43.000] 我們是希望說能夠跟
# [07:43.000 --> 07:45.000] 南部的老師一起合作
# [07:45.000 --> 07:46.000] 是
# [07:46.000 --> 07:47.000] 然後開設這樣就是
# [07:47.000 --> 07:49.040] 當然加上AIA的一些師資
# [07:49.040 --> 07:50.000] 對
# [07:50.000 --> 07:52.000] 我們在南部開設這樣的課程
# [07:52.000 --> 07:53.000] OK
# [07:53.000 --> 07:56.000] 那這個課程就是培育這樣的老師
# [07:56.000 --> 07:57.000] 我們叫種子老師
# [07:57.000 --> 07:58.000] 種子老師
# [07:58.000 --> 08:00.000] 或是種子的教官有時候
# [08:00.000 --> 08:01.000] 是是是
# [08:01.000 --> 08:04.000] 對就是讓他能夠在開始一個班一個班
# [08:04.000 --> 08:06.000] 在這個地方扎根
# [08:06.000 --> 08:07.000] 扎根
# [08:07.000 --> 08:08.000] 扎根
# [08:08.000 --> 08:10.000] 那以後就是服務在地的
# [08:10.000 --> 08:11.000] 對
# [08:11.000 --> 08:12.000] 在地的這個業者
# [08:12.000 --> 08:13.000] 是是是
# [08:13.000 --> 08:14.000] 好
# [08:14.000 --> 08:17.000] 那這個我覺得可能會比較接力氣
# [08:17.000 --> 08:18.000] 要不然
# [08:18.000 --> 08:19.000] 對
# [08:19.000 --> 08:21.000] 然後我引進什麼solution
# [08:21.000 --> 08:23.000] 這個其實不是
# [08:23.000 --> 08:24.000] 還是有段距離
# [08:24.000 --> 08:25.000] 有一段距離
# [08:25.000 --> 08:27.000] 因為如果你進一個solution
# [08:27.000 --> 08:29.000] 但是他要接受
# [08:29.000 --> 08:30.000] 這個要有人去
# [08:30.000 --> 08:31.000] 對對對
# [08:31.000 --> 08:32.000] 對
# [08:32.000 --> 08:33.000] 要有人帶進去
# [08:33.000 --> 08:34.000] 對
# [08:34.000 --> 08:35.000] 那我們覺得
# [08:35.000 --> 08:38.000] 其實像AIEP除了是做這個角色之外
# [08:38.000 --> 08:43.000] 還希望說能夠做一個類似像是
# [08:43.000 --> 08:45.000] 不要說標準的制定
# [08:45.000 --> 08:47.000] 而是說整個
# [08:47.000 --> 08:48.000] 例如說某某產業好了
# [08:48.000 --> 08:49.000] 對
# [08:49.000 --> 08:51.880] 我们他的导入的流程应该是什么
# [08:51.880 --> 08:52.380] 是
# [08:52.380 --> 08:55.380] 那这个SOP出来之后
# [08:55.380 --> 08:57.580] 大家按照这个概念去走
# [08:57.960 --> 09:00.520] 比较不会浪费
# [09:00.800 --> 09:01.500] 自我
# [09:01.500 --> 09:02.000] 人摸索的事情
# [09:02.000 --> 09:03.500] 对对对对对
# [09:03.500 --> 09:04.360] 减少在人面面面
# [09:04.360 --> 09:04.860] 对对对对
# [09:04.860 --> 09:07.120] 因为我觉得中小企业辛苦就是
# [09:07.120 --> 09:08.760] 他第一个没有这样的人
# [09:08.760 --> 09:09.260] 对
# [09:09.260 --> 09:10.260] 然后呢
# [09:10.260 --> 09:13.680] 他这方面知识可能也没有那么足够
# [09:13.680 --> 09:15.120] 那你要让他从头摸
# [09:15.120 --> 09:16.720] 他久了他觉得好烦
# [09:16.720 --> 09:17.220] 对
# [09:17.220 --> 09:18.980] 或者是他有很多失败
# [09:18.980 --> 09:20.880] 失败的可能性
# [09:20.880 --> 09:22.600] 只要稍微一点点没有的
# [09:22.600 --> 09:23.920] 那我就不要做了
# [09:23.920 --> 09:24.420] 对
# [09:24.420 --> 09:27.220] 但是我觉得以现在来说
# [09:27.220 --> 09:29.460] 也没有办法让他
# [09:29.460 --> 09:31.020] 说你不做
# [09:31.020 --> 09:33.420] 而是说我们要让你
# [09:33.420 --> 09:34.720] 第一个加速
# [09:34.720 --> 09:36.220] 第二个减少失败
# [09:36.220 --> 09:36.840] 对
# [09:36.840 --> 09:38.140] 对
# [09:38.140 --> 09:40.460] 这也是AIA的下一步
# [09:40.460 --> 09:41.420] 是是是
# [09:41.420 --> 09:44.340] 从原来只是培育一个一个的
# [09:44.340 --> 09:45.560] 公司的individual
# [09:45.560 --> 09:46.340] 或是
# [09:46.340 --> 09:47.180] 公司里面的
# [09:47.180 --> 09:49.940] 干部或公司里面的CXO level
# [09:49.940 --> 09:50.440] 对
# [09:50.440 --> 09:52.560] 我们希望说能够让他
# [09:52.560 --> 09:54.680] 再进一步的走向
# [09:54.680 --> 09:57.300] 就是去让
# [09:57.300 --> 09:58.560] 总指的老师
# [09:58.560 --> 10:00.940] 总指的顾问好了
# [10:00.940 --> 10:02.060] 能够也
# [10:02.060 --> 10:03.680] 因为他们可能在原来的领域
# [10:03.680 --> 10:05.180] 都已经很很强了
# [10:05.180 --> 10:05.680] 对
# [10:05.680 --> 10:07.340] 他现在只要加上AI的翅膀
# [10:07.340 --> 10:07.840] 对
# [10:07.840 --> 10:11.260] 他可以自己去
# [10:11.260 --> 10:14.480] 跟在地的业者产生更多的能量
# [10:14.480 --> 10:15.680] 对对对
# [10:15.680 --> 10:16.300] 是啊
# [10:16.300 --> 10:17.180] 这样很好啊
# [10:17.180 --> 10:19.800] 我觉得这样就是让百工百业
# [10:19.800 --> 10:22.060] 虽然说百工百业都要AI的人才
# [10:22.060 --> 10:23.600] 但是AI的人才
# [10:23.600 --> 10:26.100] 毕竟圈口那么大
# [10:26.100 --> 10:27.480] 那么多中小企业
# [10:27.480 --> 10:28.260] 文型企业
# [10:28.260 --> 10:30.760] 其实是没有这样的
# [10:30.760 --> 10:32.220] 没有这样的人
# [10:32.220 --> 10:35.140] 甚至没有这样的背景
# [10:35.140 --> 10:37.060] 所以要培养
# [10:37.060 --> 10:38.760] 要进去要导入
# [10:38.760 --> 10:40.940] 的确是需要很大的
# [10:40.940 --> 10:42.380] 应该说很大的助力
# [10:42.380 --> 10:42.940] 是
# [10:42.940 --> 10:43.840] 需要协助的
# [10:43.840 --> 10:44.600] 是
# [10:44.600 --> 10:47.020] 那南台在目前来说好了
# [10:47.020 --> 10:49.640] 在AI的部分
# [10:49.640 --> 10:51.900] 第一个就是校长认为说
# [10:51.900 --> 10:53.780] 刚才说大家也谢谢校长
# [10:53.780 --> 10:55.680] 就是愿意支持
# [10:55.680 --> 10:56.180] 是
# [10:56.180 --> 10:58.640] 那甚至到时候有一些老师
# [10:58.640 --> 11:00.180] 你们如果觉得也OK
# [11:00.180 --> 11:01.400] 对
# [11:01.400 --> 11:02.640] 是
# [11:02.640 --> 11:03.180] 可以来
# [11:03.180 --> 11:05.600] 那另外就是说南台现在在教学
# [11:05.600 --> 11:06.940] 实验上面
# [11:06.940 --> 11:08.360] 或是研究资源上面
# [11:08.360 --> 11:11.940] 哪些已经觉得说有适合
# [11:11.940 --> 11:15.060] 或者是也觉得可以来跟我们一起协作
# [11:15.060 --> 11:16.020] 是
# [11:16.020 --> 11:17.020] 那现在
# [11:17.020 --> 11:19.720] 在AI的教学上
# [11:19.720 --> 11:22.940] 在南台做AI相关的老师
# [11:22.940 --> 11:24.820] 在电机之工
# [11:24.820 --> 11:26.320] 主要主要为主
# [11:26.320 --> 11:27.060] 电机之工
# [11:27.060 --> 11:27.360] 是
# [11:27.360 --> 11:29.520] 有十来二十个
# [11:29.520 --> 11:30.820] 相关的
# [11:30.820 --> 11:33.900] 所以其实算也有一个师资的阵容
# [11:33.900 --> 11:34.480] 是
# [11:34.480 --> 11:37.440] 那我们现在在AI融入教学里面
# [11:37.440 --> 11:39.020] 就不只是工学院
# [11:39.020 --> 11:41.320] 我们在设计文创
# [11:41.320 --> 11:42.600] 因为我们有数位设计
# [11:42.600 --> 11:43.020] 是
# [11:43.020 --> 11:45.220] 就用了很多生成式的AI
# [11:45.220 --> 11:47.020] 生成很多像文案
# [11:47.020 --> 11:48.680] 谢谢
# [11:48.680 --> 11:53.020] 其实已经用了蛮多的生成式的AI在这一块
# [11:53.020 --> 11:55.220] 那以工程来讲
# [11:55.220 --> 11:57.020] 就是我觉得AI主要分
# [11:57.020 --> 11:59.020] 我认为三大块
# [11:59.020 --> 12:00.520] 一种是生成式AI
# [12:00.520 --> 12:01.940] 生成AI不管是讲
# [12:01.940 --> 12:03.680] CHAT GPT或者这一类
# [12:03.680 --> 12:06.680] 就是属于我们叫服务机器人
# [12:06.680 --> 12:08.220] 或者是问答机器人
# [12:08.220 --> 12:09.560] 聊天机器人
# [12:09.560 --> 12:15.020] 然后它主要是生成文字图案影片
# [12:15.020 --> 12:16.180] 甚至音乐
# [12:16.180 --> 12:18.680] 这些我们叫文创
# [12:18.680 --> 12:22.840] 这个其实在南台也用的还蛮多的
# [12:22.840 --> 12:24.680] 因为我们有数位设计学院
# [12:24.680 --> 12:26.180] 我们有我们的系
# [12:26.180 --> 12:28.680] 都跟这个文创相关的
# [12:28.680 --> 12:30.180] 好那回到工学院
# [12:30.180 --> 12:33.680] 那工学院我们当然是电机 机工 机械
# [12:33.680 --> 12:36.180] 半导体 化材
# [12:36.180 --> 12:37.180] 化材也算
# [12:37.180 --> 12:37.940] 对等等
# [12:37.940 --> 12:41.340] 那这个部分主要用在工程方面
# [12:41.340 --> 12:44.180] 就比较不是用生成式的
# [12:44.180 --> 12:45.840] 而是在解决产业里面的
# [12:46.180 --> 12:48.180] 比如说我们有很多
# [12:48.180 --> 12:50.180] 像传统产业里面
# [12:50.180 --> 12:52.680] 我觉得传统产业需要的AI
# [12:52.680 --> 12:55.180] 倒不是以生成式为主
# [12:55.180 --> 12:58.180] 而是像我觉得像视觉
# [12:58.180 --> 13:00.180] 视觉的AI跟听觉的AI
# [13:00.180 --> 13:03.180] 因为那是工厂里面的环境
# [13:03.180 --> 13:05.180] 你有做像瑕疵检测
# [13:05.180 --> 13:06.180] 对对对
# [13:06.180 --> 13:07.180] 制作化
# [13:07.180 --> 13:08.680] 结合机器手背
# [13:08.680 --> 13:11.180] 结合视觉的机器手背
# [13:11.180 --> 13:13.180] 然后听觉去看
# [13:13.180 --> 13:15.180] 这个里面的马达
# [13:15.180 --> 13:16.180] 这个车床
# [13:16.180 --> 13:18.180] 有没有杂音
# [13:18.180 --> 13:20.180] 我觉得就是视觉跟听觉
# [13:20.180 --> 13:23.180] 我觉得在一般的传统产业
# [13:23.180 --> 13:24.180] 就是微型产业
# [13:24.180 --> 13:25.680] 它也很重要
# [13:25.680 --> 13:27.180] 虽然说生成式的AI
# [13:27.180 --> 13:30.180] 我知道我们现在台湾很多在做那个H AI
# [13:30.180 --> 13:31.180] 对对对
# [13:31.180 --> 13:32.180] 做那个小小的box
# [13:32.180 --> 13:33.180] 对对对
# [13:33.180 --> 13:35.180] 放了MCU 放了GPU
# [13:35.180 --> 13:37.180] 甚至放了NPU
# [13:37.180 --> 13:39.180] 放在公司里面
# [13:39.180 --> 13:41.180] 开会 做会议记录
# [13:41.180 --> 13:42.180] 做翻译
# [13:42.180 --> 13:44.180] 你要什么问题可以问他
# [13:44.180 --> 13:45.180] 这个H AI
# [13:45.180 --> 13:47.180] 这个是一块
# [13:47.180 --> 13:50.180] 这是比较偏向办公室
# [13:50.180 --> 13:52.180] 办公室会议
# [13:52.180 --> 13:54.180] 但是另外一块是自动化
# [13:54.180 --> 13:56.180] 太多传统产部
# [13:56.180 --> 13:57.180] 切削
# [13:57.180 --> 13:59.180] 这种生产线
# [13:59.180 --> 14:01.180] 它要导入的是自动化的
# [14:01.180 --> 14:03.180] 机器手背
# [14:03.180 --> 14:05.180] 瑕疵检测
# [14:05.180 --> 14:08.180] 这里面很需要视觉跟听觉
# [14:08.180 --> 14:09.180] 那刚好
# [14:09.180 --> 14:11.180] 因为我过去在AI
# [14:11.180 --> 14:13.180] 我会把用在农业
# [14:13.180 --> 14:14.180] 对对对
# [14:14.180 --> 14:15.180] 过去十年来
# [14:15.180 --> 14:17.180] 其实也累积了一些就是
# [14:17.180 --> 14:21.180] AI视觉跟AI听觉的这些经验
# [14:21.180 --> 14:25.180] 怎么去建制听觉跟视觉的这种AI的模型
# [14:25.180 --> 14:27.180] 所以我在两年多以前
# [14:27.180 --> 14:29.180] 我就开始打造一个平台
# [14:29.180 --> 14:32.180] 我把它叫做AI Maker
# [14:32.180 --> 14:36.180] 这个平台就是专门来培养学生
# [14:36.180 --> 14:39.180] 自己来建视觉的AI模型
# [14:39.180 --> 14:40.180] 听觉的AI模型
# [14:40.180 --> 14:42.180] 就在那边实作
# [14:42.180 --> 14:44.180] 我们有一些理论的课程
# [14:44.180 --> 14:45.180] 你刚讲
# [14:45.180 --> 14:46.180] 不管是CNN
# [14:46.180 --> 14:47.180] 或者什么YOLO
# [14:47.180 --> 14:48.180] 或者什么
# [14:48.180 --> 14:50.180] 那个是理论
# [14:50.180 --> 14:51.180] 对对对
# [14:51.180 --> 14:52.180] 我这个平台
# [14:52.180 --> 14:53.180] 因为我在科大
# [14:53.180 --> 14:56.180] 所以我要把科大定位就是实作型的AI
# [14:56.180 --> 14:57.180] 是是是
# [14:57.180 --> 15:00.180] 我这个平台就是专门是让学生
# [15:00.180 --> 15:01.180] 或者刚讲
# [15:01.180 --> 15:02.180] 种子老师
# [15:02.180 --> 15:04.180] 来玩的
# [15:04.180 --> 15:05.180] 太好了
# [15:05.180 --> 15:06.180] 就是实作
# [15:06.180 --> 15:07.180] 对对对
# [15:07.180 --> 15:08.180] 实作
# [15:08.180 --> 15:09.180] 这个实作就是说
# [15:09.180 --> 15:11.180] 我从数据收集开始
# [15:11.180 --> 15:12.180] 比如我几个例子
# [15:12.180 --> 15:13.180] 比如我这桌子上
# [15:13.180 --> 15:14.180] 我买了一个
# [15:14.180 --> 15:16.180] 比如说我们附近很多工厂是做螺丝的
# [15:16.180 --> 15:18.180] 螺丝MOD或螺丝
# [15:18.180 --> 15:20.180] 可是如果你要真的导入自动化
# [15:20.180 --> 15:21.180] 你要能够辨别
# [15:21.180 --> 15:22.180] 对
# [15:22.180 --> 15:24.180] 然后去驱动那个机器手背
# [15:24.180 --> 15:25.180] 是是是
# [15:25.180 --> 15:26.180] 做什么什么
# [15:26.180 --> 15:28.180] 所以我就可以把
# [15:28.180 --> 15:31.180] 比如说把零件放在桌子上
# [15:31.180 --> 15:32.180] 然后
# [15:32.180 --> 15:34.180] 对不起用手机去拍嘛
# [15:34.180 --> 15:35.180] 质量手机
# [15:35.180 --> 15:36.180] 对对对
# [15:36.180 --> 15:38.180] 拍完就上传到我的平台
# [15:38.180 --> 15:39.180] 对
# [15:39.180 --> 15:40.180] 然后就可以开始做Labeling
# [15:40.180 --> 15:41.180] 啊OK
# [15:41.180 --> 15:42.180] 看你要标它的瑕疵
# [15:42.180 --> 15:43.180] 或者标它的尺寸
# [15:43.180 --> 15:45.180] 标它的分类分级
# [15:45.180 --> 15:46.180] 是
# [15:46.180 --> 15:48.180] 然后再来我就帮你训练模型
# [15:48.180 --> 15:50.180] 那训练模型我就需要GPU了
# [15:50.180 --> 15:51.180] 嗯嗯嗯
# [15:51.180 --> 15:54.180] 所以我这个平台已经去串联很多学校的GPU了
# [15:54.180 --> 15:55.180] 嗯嗯嗯
# [15:55.180 --> 15:56.180] GPU我们台也有
# [15:56.180 --> 15:57.180] 嗯嗯嗯
# [15:57.180 --> 15:58.180] 清大也有
# [15:58.180 --> 15:59.180] 嗯嗯嗯
# [15:59.180 --> 16:00.180] 所以我在
# [16:00.180 --> 16:01.180] 我再召集就是说
# [16:01.180 --> 16:03.180] 这个叫算力联盟啦
# [16:03.180 --> 16:04.180] 太好了
# [16:04.180 --> 16:05.180] 就是大家有算力的初算力
# [16:05.180 --> 16:06.180] 对对对
# [16:06.180 --> 16:07.180] 然后透过
# [16:07.180 --> 16:09.180] 我是用那个叫K8S啦
# [16:09.180 --> 16:10.180] 嗯
# [16:10.180 --> 16:11.180] 你可以把不同
# [16:11.180 --> 16:12.180] 不同单位的
# [16:12.180 --> 16:14.180] GPU就可以纳入
# [16:14.180 --> 16:16.180] 就统一的管理啦
# [16:16.180 --> 16:17.180] 对
# [16:17.180 --> 16:18.180] 运算那样子
# [16:18.180 --> 16:20.180] 所以我把这个模型丢出去之后
# [16:20.180 --> 16:22.180] 训练训练回来了
# [16:22.180 --> 16:24.180] 然后我就可以载入到
# [16:24.180 --> 16:26.180] 比如说智慧手机
# [16:26.180 --> 16:27.180] 智慧眼镜
# [16:27.180 --> 16:28.180] 对呀
# [16:28.180 --> 16:29.180] 因为我们在工厂里面有时候
# [16:29.180 --> 16:30.180] 对
# [16:30.180 --> 16:31.180] 拿手机不方便嘛
# [16:31.180 --> 16:32.180] 那这个参数很小耶
# [16:32.180 --> 16:33.180] 对
# [16:33.180 --> 16:34.180] 这个不是很大的一个
# [16:34.180 --> 16:35.180] 嗯
# [16:35.180 --> 16:36.180] 那这很棒
# [16:36.180 --> 16:37.180] 平台
# [16:37.180 --> 16:38.180] 嗯嗯
# [16:38.180 --> 16:39.180] 但是就是说
# [16:39.180 --> 16:40.180] 我会结有不同的终端
# [16:40.180 --> 16:41.180] 好像智慧眼镜
# [16:41.180 --> 16:42.180] 嗯嗯嗯
# [16:42.180 --> 16:43.180] 像AI
# [16:43.180 --> 16:44.180] AR智慧
# [16:44.180 --> 16:45.180] 像
# [16:45.180 --> 16:46.180] 像这边
# [16:46.180 --> 16:47.180] 刚好
# [16:47.180 --> 16:48.180] 就是来做这种
# [16:48.180 --> 16:49.180] 哦太好了
# [16:49.180 --> 16:52.180] 像这个AR的智慧眼镜
# [16:52.180 --> 16:53.180] 嗯
# [16:53.180 --> 16:54.180] 它里面其实就有GPU了
# [16:54.180 --> 16:55.180] 哦
# [16:55.180 --> 16:56.180] 就是说
# [16:56.180 --> 16:58.180] 我如果让它跑起来的话
# [16:58.180 --> 16:59.180] 它其实
# [16:59.180 --> 17:00.180] 它已经可以做
# [17:00.180 --> 17:01.180] 做很多事情
# [17:01.180 --> 17:02.180] 嗯
# [17:02.180 --> 17:03.180] 但我们讲一下
# [17:03.180 --> 17:04.180] 有一段计算
# [17:04.180 --> 17:05.180] 刚讲讲那个HAI
# [17:05.180 --> 17:06.180] 嗯嗯
# [17:06.180 --> 17:07.180] 那它这个一般
# [17:07.180 --> 17:08.180] 我把它叫做终端AI
# [17:08.180 --> 17:09.180] 对
# [17:09.180 --> 17:10.180] 因为我的GPU已经在这里了
# [17:10.180 --> 17:11.180] 哦
# [17:11.180 --> 17:13.180] 我用相机一拍模型在这里
# [17:13.180 --> 17:14.180] 嗯
# [17:14.180 --> 17:15.180] 我立刻可以做很多辨识动作
# [17:15.180 --> 17:16.180] 对对对
# [17:16.180 --> 17:17.180] 比如指导它操作
# [17:17.180 --> 17:18.180] 对
# [17:18.180 --> 17:19.180] 因为实作嘛
# [17:19.180 --> 17:20.180] 嗯嗯
# [17:20.180 --> 17:21.180] 所以我刚刚提到说
# [17:21.180 --> 17:22.180] 我的平台就是
# [17:22.180 --> 17:23.180] 收集资料
# [17:23.180 --> 17:24.180] 上传标记
# [17:24.180 --> 17:25.180] 训练
# [17:25.180 --> 17:26.180] 下载
# [17:26.180 --> 17:27.180] 验证
# [17:27.180 --> 17:28.180] 嗯
# [17:28.180 --> 17:29.180] 我这是人才培育啦
# [17:29.180 --> 17:30.180] 嗯
# [17:30.180 --> 17:31.180] 验证
# [17:31.180 --> 17:32.180] 验证就是我会帮它的模型
# [17:32.180 --> 17:33.180] 评分
# [17:33.180 --> 17:34.180] 哦
# [17:34.180 --> 17:35.180] 还可以帮它评分哦
# [17:35.180 --> 17:36.180] 哦
# [17:36.180 --> 17:38.180] 帮它评量它的模型好坏嘛
# [17:38.180 --> 17:40.180] 那怎么评分就是说
# [17:40.180 --> 17:41.180] 那你要辨识的东西
# [17:41.180 --> 17:44.180] 我会用生成式AI去生成一个
# [17:44.180 --> 17:45.180] 好像诶那个考卷
# [17:45.180 --> 17:46.180] 考卷
# [17:46.180 --> 17:47.180] 对对对
# [17:47.180 --> 17:48.180] 比如说诶你快让它进
# [17:48.180 --> 17:50.180] 诶我会出现很多这个不同的object
# [17:50.180 --> 17:51.180] 嗯
# [17:51.180 --> 17:52.180] 那你能不能辨识出来
# [17:52.180 --> 17:53.180] 嗯嗯嗯
# [17:53.180 --> 17:54.180] 框对不对嘛
# [17:54.180 --> 17:55.180] 框也很重要嘛
# [17:55.180 --> 17:56.180] 嗯
# [17:56.180 --> 17:57.180] 你框对不对
# [17:57.180 --> 17:58.180] 啊level对不对嘛
# [17:58.180 --> 18:00.180] 啊如果平台不喜欢你再去优化
# [18:00.180 --> 18:01.180] 嗯
# [18:01.180 --> 18:02.180] 增加你的training data
# [18:02.180 --> 18:03.180] 嗯嗯嗯
# [18:03.180 --> 18:04.180] 或者你调整那个参数嘛
# [18:04.180 --> 18:05.180] 然后这样这样嘛
# [18:05.180 --> 18:06.180] 玩个几次
# [18:06.180 --> 18:07.180] 它就
# [18:07.180 --> 18:08.180] 我就是说
# [18:08.180 --> 18:09.180] 因为我不是
# [18:09.180 --> 18:10.180] 我不是
# [18:10.180 --> 18:12.180] 要做很高深的东西
# [18:12.180 --> 18:14.180] 因为如果真的要做产业直接剪辑
# [18:14.180 --> 18:15.180] 对吧
# [18:15.180 --> 18:16.180] 那是老师再去带
# [18:16.180 --> 18:17.180] 嗯嗯嗯嗯
# [18:17.180 --> 18:19.180] 那这个是刚才就是培养那个员工
# [18:19.180 --> 18:20.180] 对
# [18:20.180 --> 18:21.180] 一个基础啦
# [18:21.180 --> 18:22.180] 对
# [18:22.180 --> 18:23.180] 那知道说哦什么叫做视觉AI
# [18:23.180 --> 18:25.180] 可是这个培养中指教师也很好
# [18:25.180 --> 18:26.180] 诶对这个培养
# [18:26.180 --> 18:27.180] 对这个是中指教师
# [18:27.180 --> 18:28.180] 然后它再去带
# [18:28.180 --> 18:31.180] 因为我们想的不是去培养
# [18:31.180 --> 18:33.180] 那个已经本来就是职工的人
# [18:33.180 --> 18:34.180] 啊对对不是不是
# [18:34.180 --> 18:35.180] 不是
# [18:35.180 --> 18:37.180] 反而是那些它原来念机械化材
# [18:37.180 --> 18:38.180] 对
# [18:38.180 --> 18:39.180] 对那些是真的领域专家
# [18:39.180 --> 18:40.180] 它现在是
# [18:40.180 --> 18:43.180] 就是说啊我觉得AI是有点印象
# [18:43.180 --> 18:44.180] 是
# [18:44.180 --> 18:45.180] 一知半解
# [18:45.180 --> 18:46.180] 但是它对产业很熟
# [18:46.180 --> 18:47.180] 对
# [18:47.180 --> 18:48.180] 它对Domain Knowledge很熟
# [18:48.180 --> 18:49.180] 是啊
# [18:49.180 --> 18:50.180] 所以我们今天要培养
# [18:50.180 --> 18:52.180] 反而是用老师您开
# [18:52.180 --> 18:53.180] 校长您开发的这一套
# [18:53.180 --> 18:54.180] 对
# [18:54.180 --> 18:55.180] 去让他们说哦原来AI没那么难
# [18:55.180 --> 18:56.180] 对是是是
# [18:56.180 --> 18:59.180] 我其实就是希望说AI的门槛降低
# [18:59.180 --> 19:01.180] 而且这个平台里面基本上是No Code
# [19:01.180 --> 19:02.180] 对对
# [19:02.180 --> 19:04.180] 你不用写这个什么Java
# [19:04.180 --> 19:05.180] 对
# [19:05.180 --> 19:06.180] 不用写什么Python
# [19:06.180 --> 19:07.180] 对对
# [19:07.180 --> 19:08.180] 就是让它操作
# [19:08.180 --> 19:09.180] 对
# [19:09.180 --> 19:10.180] 然后它就会有这个Domain Knowledge
# [19:10.180 --> 19:11.180] 对
# [19:11.180 --> 19:12.180] 因为对于什么机械化
# [19:12.180 --> 19:14.180] 它强的可能是这个传热流
# [19:14.180 --> 19:16.180] 可能是那个洁净热力学
# [19:16.180 --> 19:18.180] 但它挺像说哇这个
# [19:18.180 --> 19:20.180] 这个我要我去写Code啊
# [19:20.180 --> 19:22.180] 对啊对啊就比较辛苦
# [19:22.180 --> 19:23.180] 对对对
# [19:23.180 --> 19:25.180] 所以这个只要视觉就是像手机也可以
# [19:25.180 --> 19:26.180] 嗯嗯嗯
# [19:26.180 --> 19:28.180] 首先就这样我跑那个模型的时候
# [19:28.180 --> 19:29.180] 我就可以辨识啊
# [19:29.180 --> 19:30.180] 嗯嗯嗯
# [19:30.180 --> 19:31.180] 可以立刻辨识
# [19:31.180 --> 19:34.180] 所以视觉方面不管是手机智慧眼镜
# [19:34.180 --> 19:36.180] Camera反正只要有能够看的
# [19:36.180 --> 19:37.180] 嗯嗯嗯
# [19:37.180 --> 19:38.180] 我都可以载入啦
# [19:38.180 --> 19:39.180] 嗯嗯嗯
# [19:39.180 --> 19:40.180] 那后面包含说
# [19:40.180 --> 19:42.180] 我有我再结合一些叫机器手背
# [19:42.180 --> 19:43.180] 对AM啊
# [19:43.180 --> 19:44.180] 机器手背这样的Camera
# [19:44.180 --> 19:45.180] 嗯嗯嗯
# [19:45.180 --> 19:49.180] 然后这个模型就可以在我们平台开发了
# [19:49.180 --> 19:50.180] 然后下载
# [19:50.180 --> 19:51.180] 嗯嗯嗯
# [19:51.180 --> 19:52.180] 那这个模型就刚才
# [19:52.180 --> 19:53.180] 我看到这些螺丝钉
# [19:53.180 --> 19:56.180] 那你就去结合那个手背去把它挑出来啊
# [19:56.180 --> 19:57.180] 嗯嗯嗯
# [19:57.180 --> 19:59.180] 比如瑕疵检测分级分类
# [19:59.180 --> 20:00.180] 嗯嗯嗯
# [20:00.180 --> 20:01.180] 就变成视觉加自动
# [20:01.180 --> 20:02.180] 嗯嗯嗯
# [20:02.180 --> 20:04.180] 可以在我这个平台上面实现
# [20:04.180 --> 20:05.180] 嗯嗯嗯
# [20:05.180 --> 20:06.180] 就完啦就完
# [20:06.180 --> 20:07.180] 嗯嗯嗯
# [20:07.180 --> 20:09.180] 那视觉方面其实就很多好可以玩了
# [20:09.180 --> 20:10.180] 嗯
# [20:10.180 --> 20:12.180] 然后我这个平台还有一个特色
# [20:12.180 --> 20:14.180] 你在做这个视觉辨识的时候
# [20:14.180 --> 20:16.180] 我可以做全球的转播啦
# [20:16.180 --> 20:18.180] 我已经把它做到转播了
# [20:18.180 --> 20:19.180] 转播的意思
# [20:19.180 --> 20:21.180] 转播意思就是说你在操作的时候
# [20:21.180 --> 20:22.180] 我可以帮你录影
# [20:22.180 --> 20:23.180] 啊
# [20:23.180 --> 20:25.180] 我可以帮你转播出去给别人看
# [20:25.180 --> 20:26.180] 哦
# [20:26.180 --> 20:28.180] 或别人可能就远端的指导
# [20:28.180 --> 20:29.180] 是是是
# [20:29.180 --> 20:30.180] 或者你在做示范
# [20:30.180 --> 20:31.180] 是
# [20:31.180 --> 20:32.180] 因为我让它有趣嘛
# [20:32.180 --> 20:33.180] 有趣就是说在
# [20:33.180 --> 20:34.180] 因为我把它当成人才
# [20:34.180 --> 20:36.180] 可以在班上教一个老师
# [20:36.180 --> 20:37.180] 带带一些学生
# [20:37.180 --> 20:38.180] 嗯
# [20:38.180 --> 20:39.180] 我把它当成一个专案的一个
# [20:39.180 --> 20:40.180] 嗯
# [20:40.180 --> 20:41.180] 老师带学生
# [20:41.180 --> 20:43.180] 所以刚刚那个资料的拍照
# [20:43.180 --> 20:44.180] 是学生一起啦
# [20:44.180 --> 20:45.180] 是一群
# [20:45.180 --> 20:46.180] 嗯
# [20:46.180 --> 20:47.180] 大家一起去
# [20:47.180 --> 20:48.180] 收集的台块嘛
# [20:48.180 --> 20:49.180] 然后大家一起去标嘛
# [20:49.180 --> 20:50.180] 嗯嗯嗯
# [20:50.180 --> 20:51.180] 就集体创作啦
# [20:51.180 --> 20:52.180] 嗯嗯
# [20:52.180 --> 20:53.180] 集体创作
# [20:53.180 --> 20:54.180] 好然后你下来
# [20:54.180 --> 20:55.180] 验证的说我可以帮他做广播
# [20:55.180 --> 20:56.180] 嗯
# [20:56.180 --> 20:57.180] 就是可以观摩啦
# [20:57.180 --> 20:58.180] 大家可以去观摩
# [20:58.180 --> 20:59.180] 嗯
# [20:59.180 --> 21:00.180] 可以去看
# [21:00.180 --> 21:01.180] 就让他很好玩
# [21:01.180 --> 21:02.180] 嗯
# [21:02.180 --> 21:03.180] 啊
# [21:03.180 --> 21:04.180] 这样子run了几次之后
# [21:04.180 --> 21:05.180] 我觉得他们对
# [21:05.180 --> 21:06.180] 嗯
# [21:06.180 --> 21:07.180] 就有概念了
# [21:07.180 --> 21:08.180] 嗯
# [21:08.180 --> 21:09.180] 嗯
# [21:09.180 --> 21:11.180] 啊因为我做十年的农业
# [21:11.180 --> 21:12.180] 所以一开始玩的时候
# [21:12.180 --> 21:13.180] 我们就玩水果
# [21:13.180 --> 21:14.180] 嗯
# [21:14.180 --> 21:15.180] 哦对
# [21:15.180 --> 21:16.180] 就来检测那些水果
# [21:16.180 --> 21:17.180] 对
# [21:17.180 --> 21:18.180] 松江获米啊
# [21:18.180 --> 21:19.180] 像那种
# [21:19.180 --> 21:20.180] 反正很多
# [21:20.180 --> 21:21.180] 这个我桌上可以摆满很多水果
# [21:21.180 --> 21:22.180] 对
# [21:22.180 --> 21:23.180] 对
# [21:23.180 --> 21:24.180] 大家就去排
# [21:24.180 --> 21:25.180] 就去上传标记训练模型
# [21:25.180 --> 21:26.180] 对
# [21:26.180 --> 21:27.180] 对
# [21:27.180 --> 21:28.180] 辨识然后互相比赛
# [21:28.180 --> 21:29.180] 对
# [21:29.180 --> 21:30.180] 因为我会帮你评分嘛
# [21:30.180 --> 21:31.180] 对
# [21:31.180 --> 21:32.180] 我会帮你评分
# [21:32.180 --> 21:33.180] 对
# [21:33.180 --> 21:34.180] 这是一个视觉的
# [21:34.180 --> 21:35.180] 听觉的话呢
# [21:35.180 --> 21:36.180] 刚好因为我
# [21:36.180 --> 21:37.180] 上次讲凤梨嘛
# [21:37.180 --> 21:38.180] 是
# [21:38.180 --> 21:39.180] 所以其实我有发明一个
# [21:39.180 --> 21:41.180] 这个就是AI的敲击棒
# [21:41.180 --> 21:43.180] 这个敲击棒里面已经有晶片了
# [21:43.180 --> 21:44.180] 哦
# [21:44.180 --> 21:45.180] 就是一个AI的chip
# [21:45.180 --> 21:46.180] 是
# [21:46.180 --> 21:47.180] 所以我只要下载不同的模型
# [21:47.180 --> 21:48.180] 嗯
# [21:48.180 --> 21:50.180] 这一根就有不同的功能了
# [21:50.180 --> 21:51.180] 比如说我如果要敲凤梨
# [21:51.180 --> 21:52.180] 我就敲凤梨
# [21:52.180 --> 21:53.180] 那敲西瓜
# [21:53.180 --> 21:54.180] 我就敲西瓜
# [21:54.180 --> 21:55.180] 敲什么墙壁
# [21:55.180 --> 21:56.180] 敲砖
# [21:56.180 --> 21:57.180] 敲什么
# [21:57.180 --> 21:58.180] 啊
# [21:58.180 --> 21:59.180] 那这个工业里面
# [21:59.180 --> 22:00.180] 其实很多是靠声音
# [22:00.180 --> 22:01.180] 对
# [22:01.180 --> 22:02.180] 没有错
# [22:02.180 --> 22:03.180] 那我就是可以去收集这些声音
# [22:03.180 --> 22:05.180] 所以它本身也可以收集
# [22:05.180 --> 22:06.180] 哦太好了
# [22:06.180 --> 22:07.180] 上传
# [22:07.180 --> 22:08.180] 标记
# [22:08.180 --> 22:09.180] 训练
# [22:09.180 --> 22:10.180] 下载
# [22:10.180 --> 22:11.180] 哎
# [22:11.180 --> 22:12.180] 校长
# [22:12.180 --> 22:13.180] 这个可以让我拍一下吗
# [22:13.180 --> 22:14.180] 可以可以可以
# [22:14.180 --> 22:15.180] 没有问题
# [22:15.180 --> 22:17.180] 我有另外一个手机
# [22:17.180 --> 22:21.180] 这个这个这个这个就可以
# [22:21.180 --> 22:23.180] 我主要是让它好玩啦
# [22:23.180 --> 22:24.180] 哦
# [22:24.180 --> 22:25.180] 这个很有用啊
# [22:25.180 --> 22:26.180] 这这这
# [22:26.180 --> 22:27.180] 这应该不会只有好玩而已
# [22:27.180 --> 22:28.180] 是是是
# [22:31.180 --> 22:33.180] 校长你做的没问题
# [22:33.180 --> 22:34.180] 我做我做
# [22:34.180 --> 22:35.180] 对你们是发明人啊
# [22:35.180 --> 22:36.180] 是是是
# [22:36.180 --> 22:37.180] 眼镜不是我发明
# [22:37.180 --> 22:38.180] 眼镜是买的
# [22:38.180 --> 22:39.180] 但是这个是我发明
# [22:39.180 --> 22:41.180] 这个有拿到台湾的专利
# [22:41.180 --> 22:42.180] 哦
# [22:42.180 --> 22:43.180] 中华民国的专利
# [22:43.180 --> 22:45.180] 所以这个的话就是您稍微再改造一下
# [22:45.180 --> 22:46.180] 哎这个直接买就可以了
# [22:46.180 --> 22:47.180] 直接买
# [22:47.180 --> 22:48.180] 这个这个是外面的
# [22:48.180 --> 22:49.180] 哦真的
# [22:49.180 --> 22:50.180] 可是模型
# [22:50.180 --> 22:51.180] 模型要让它下载
# [22:51.180 --> 22:52.180] 对对对
# [22:52.180 --> 22:53.180] 模型是我们的
# [22:53.180 --> 22:54.180] 啊
# [22:54.180 --> 22:55.180] 但是硬底是买的
# [22:55.180 --> 22:56.180] 哦
# [22:56.180 --> 22:57.180] 像国内国内不是有叫佐征吗
# [22:57.180 --> 22:58.180] 佐征我知道
# [22:58.180 --> 22:59.180] 佐征也在做AR之类的
# [22:59.180 --> 23:00.180] 对对对
# [23:00.180 --> 23:03.180] 现在很多美国的公司像Meta
# [23:03.180 --> 23:04.180] 嗯
# [23:04.180 --> 23:05.180] 就它也有AR之类的
# [23:05.180 --> 23:10.180] 所以我们也是在拥有不同款项的AR之类的眼镜
# [23:10.180 --> 23:11.180] 嗯嗯嗯
# [23:11.180 --> 23:13.180] 所以以后会有不同不同款项
# [23:13.180 --> 23:17.180] 有的有的AR它像Meta的比较便宜
# [23:17.180 --> 23:19.180] Meta是可以像有点像全装饰
# [23:19.180 --> 23:20.180] 对对对
# [23:20.180 --> 23:22.180] 啊可是它很便宜一万五千块
# [23:22.180 --> 23:23.180] 嗯
# [23:23.180 --> 23:24.180] 现在那个佐征的是像这样子
# [23:24.180 --> 23:25.180] 嗯
# [23:25.180 --> 23:26.180] 可是它要六七万啊
# [23:26.180 --> 23:27.180] 嗯
# [23:27.180 --> 23:28.180] 所以有时候比较贵
# [23:28.180 --> 23:29.180] 嗯
# [23:29.180 --> 23:30.180] 没关系就是便宜的贵的
# [23:30.180 --> 23:33.180] 我们都可以去去去整进来
# [23:33.180 --> 23:34.180] 对对
# [23:34.180 --> 23:35.180] 所以我这个平台就希望说
# [23:35.180 --> 23:37.180] 将来视觉听觉的
# [23:37.180 --> 23:39.180] 然后结合机器所备做详细检测
# [23:39.180 --> 23:41.180] 这个都是落地啊
# [23:41.180 --> 23:42.180] 嗯嗯嗯
# [23:42.180 --> 23:43.180] 但是落地我希望
# [23:43.180 --> 23:45.180] 我们在平台上面学生训练的
# [23:45.180 --> 23:47.180] 或者刚刚有工程师训练的模型
# [23:47.180 --> 23:49.180] 可以载入嘛
# [23:49.180 --> 23:50.180] 嗯嗯嗯
# [23:50.180 --> 23:51.180] 就可以验证
# [23:51.180 --> 23:52.180] 嗯
# [23:52.180 --> 23:53.180] 因为台湾硬体很强
# [23:53.180 --> 23:54.180] 我们现在一直在里面
# [23:54.180 --> 23:55.180] 对
# [23:55.180 --> 23:56.180] 最头也不是说头痛
# [23:56.180 --> 23:58.180] 最需要解决就是软硬整合的问题
# [23:58.180 --> 23:59.180] 是是是
# [23:59.180 --> 24:02.180] 包含刚其实校长也有点到几个
# [24:02.180 --> 24:03.180] 对
# [24:03.180 --> 24:04.180] 就是可能机器人
# [24:04.180 --> 24:05.180] 对
# [24:05.180 --> 24:06.180] 没错
# [24:06.180 --> 24:08.180] 然后我们上礼拜五去汉祥
# [24:08.180 --> 24:10.180] 最大问题就是
# [24:10.180 --> 24:12.180] 就是认
# [24:12.180 --> 24:13.180] 反正因为
# [24:13.180 --> 24:14.180] 因为无人机
# [24:14.180 --> 24:15.180] 对
# [24:15.180 --> 24:16.180] 因为里面
# [24:16.180 --> 24:18.180] 里面拆开的每一个都是产业
# [24:18.180 --> 24:19.180] 射控
# [24:19.180 --> 24:20.180] 那个射控
# [24:20.180 --> 24:21.180] 然后图控什么
# [24:21.180 --> 24:22.180] 对对对
# [24:22.180 --> 24:23.180] 我听他们在讲说
# [24:23.180 --> 24:24.180] 有飞控
# [24:24.180 --> 24:25.180] 对我都听完以后就说
# [24:25.180 --> 24:27.180] 哦啊我们对无人机的了解太少
# [24:27.180 --> 24:28.180] 或者是说
# [24:28.180 --> 24:30.180] 台湾在无人机上面
# [24:30.180 --> 24:32.180] 好像都只有琢磨在硬体
# [24:32.180 --> 24:33.180] 哦
# [24:33.180 --> 24:34.180] 不是好像就是
# [24:34.180 --> 24:35.180] 是哦
# [24:35.180 --> 24:36.180] 那那些
# [24:36.180 --> 24:37.180] 因为它是
# [24:37.180 --> 24:39.180] 线上到很复杂的空间运算
# [24:39.180 --> 24:40.180] 对
# [24:40.180 --> 24:42.180] 然后里面还会谈到很多很
# [24:42.180 --> 24:43.180] 对
# [24:43.180 --> 24:44.180] 很很假设
# [24:44.180 --> 24:45.180] 简单讲一个情景
# [24:45.180 --> 24:46.180] 假设今天没有GPS
# [24:46.180 --> 24:47.180] 你还能飞吗
# [24:47.180 --> 24:48.180] 对
# [24:48.180 --> 24:49.180] 对你还能飞吗
# [24:49.180 --> 24:51.180] 如果自己对你怎么还
# [24:51.180 --> 24:52.180] 然后群机怎么飞
# [24:52.180 --> 24:53.180] 对
# [24:53.180 --> 24:54.180] 你一只飞过来很简单
# [24:54.180 --> 24:56.180] 如果群机假设
# [24:56.180 --> 24:58.180] 这一只假设主控机挂了
# [24:58.180 --> 24:59.180] 对
# [24:59.180 --> 25:00.180] 或是被射掉
# [25:00.180 --> 25:01.180] 对
# [25:01.180 --> 25:04.180] 然后呢哪一只可以取而代之
# [25:04.180 --> 25:05.180] 对对对
# [25:05.180 --> 25:06.180] 变成主控
# [25:06.180 --> 25:07.180] 变成leader
# [25:07.180 --> 25:08.180] 变成leader
# [25:08.180 --> 25:09.180] 我听完说哇这个
# [25:09.180 --> 25:10.180] 那演算法不简单啊
# [25:10.180 --> 25:11.180] 那不简单啊
# [25:11.180 --> 25:12.180] 想说它都飞在上面
# [25:12.180 --> 25:13.180] 你也没有办法说
# [25:13.180 --> 25:14.180] 你没有办法指挥
# [25:14.180 --> 25:15.180] 说你变了
# [25:15.180 --> 25:16.180] 没办法啊
# [25:16.180 --> 25:17.180] 对对
# [25:17.180 --> 25:18.180] 没办法
# [25:18.180 --> 25:19.180] 要分散是自我去
# [25:19.180 --> 25:20.180] 但是那但是那些都不在台湾身上
# [25:20.180 --> 25:21.180] 哦
# [25:21.180 --> 25:22.180] 现在麻烦就是这个
# [25:22.180 --> 25:23.180] 这些都我们其实没有
# [25:23.180 --> 25:24.180] 哦
# [25:24.180 --> 25:25.180] 那这个其实都应该
# [25:25.180 --> 25:26.180] 就应该考比较上一次
# [25:26.180 --> 25:27.180] 对
# [25:27.180 --> 25:28.180] 对
# [25:28.180 --> 25:29.180] 就是我们都没有的
# [25:29.180 --> 25:30.180] 那可不可以
# [25:30.180 --> 25:31.180] 那我们也有一个
# [25:31.180 --> 25:32.180] 那我们也有一个
# [25:32.180 --> 25:33.180] 那我们也有一个
# [25:33.180 --> 25:35.180] 那可能是几年前
# [25:35.180 --> 25:37.180] 几年前其实台湾对这件事情
# [25:37.180 --> 25:38.180] 也没有很注意
# [25:38.180 --> 25:39.180] 是啦
# [25:39.180 --> 25:40.180] 好
# [25:40.180 --> 25:41.180] 然后等到要注意的时候
# [25:41.180 --> 25:42.180] 哇断层了
# [25:42.180 --> 25:43.180] 断层了
# [25:43.180 --> 25:44.180] 没人了
# [25:44.180 --> 25:45.180] 对离此那长得多了
# [25:45.180 --> 25:46.180] 对第一个那个
# [25:46.180 --> 25:47.180] 长得厉害的人
# [25:47.180 --> 25:48.180] 这么厉害的人
# [25:48.180 --> 25:49.180] 就是你要出街不是没有
# [25:49.180 --> 25:50.180] 对
# [25:50.180 --> 25:51.180] 但是你要中高阶级就是没有
# [25:51.180 --> 25:52.180] 对
# [25:52.180 --> 25:53.180] 那你没有就是
# [25:53.180 --> 25:54.180] 你现在也来不及生了
# [25:54.180 --> 25:55.180] 是是是
# [25:55.180 --> 25:56.180] 没办法
# [25:56.180 --> 25:57.180] 所以这件事情是
# [25:57.180 --> 25:59.180] 其实国家也很头痛
# [25:59.180 --> 26:00.180] 对啦
# [26:00.180 --> 26:01.180] 要加快了
# [26:01.180 --> 26:02.180] 对啊
# [26:02.180 --> 26:03.180] 那只是看用什么方法
# [26:03.180 --> 26:04.180] 种兵啊
# [26:04.180 --> 26:05.180] 对啊
# [26:05.180 --> 26:06.180] 那包含就是说
# [26:06.180 --> 26:07.180] 我们现在回来讲这个
# [26:07.180 --> 26:08.180] 对
# [26:08.180 --> 26:09.180] 就是其实这种
# [26:09.180 --> 26:11.180] 更直接可以落地的
# [26:11.180 --> 26:12.180] 对
# [26:12.180 --> 26:13.180] 现在很直
# [26:13.180 --> 26:14.180] 因为
# [26:14.180 --> 26:16.180] 那个反正
# [26:16.180 --> 26:17.180] 关税的事情吧
# [26:17.180 --> 26:18.180] 对啊
# [26:18.180 --> 26:19.180] 那我们现在如果
# [26:19.180 --> 26:21.180] 那其实有两派说法
# [26:21.180 --> 26:22.180] 或是多派说法
# [26:22.180 --> 26:23.180] 有一派是说
# [26:23.180 --> 26:24.180] 就趁这个机会
# [26:24.180 --> 26:26.180] 让没有竞争力的就
# [26:26.180 --> 26:27.180] 淘汰
# [26:27.180 --> 26:28.180] 我听过
# [26:28.180 --> 26:29.180] 我听过这样
# [26:29.180 --> 26:30.180] 好
# [26:30.180 --> 26:31.180] 但是
# [26:31.180 --> 26:32.180] 但是这件事情是
# [26:32.180 --> 26:33.180] 是
# [26:33.180 --> 26:34.180] 是
# [26:34.180 --> 26:35.180] 是
# [26:35.180 --> 26:36.180] 是
# [26:36.180 --> 26:37.180] 就是这个
# [26:37.180 --> 26:38.180] 你嘴巴可以这样讲
# [26:38.180 --> 26:39.180] 但事实上是不能这样做的
# [26:39.180 --> 26:40.180] 对啦
# [26:40.180 --> 26:41.180] 对对对
# [26:41.180 --> 26:42.180] 是不能这样做的
# [26:42.180 --> 26:43.180] 那有什么方法是可以
# [26:43.180 --> 26:44.180] 把大家拉起来
# [26:44.180 --> 26:45.180] 拉起来
# [26:45.180 --> 26:46.180] 对
# [26:46.180 --> 26:47.180] 拉起来
# [26:47.180 --> 26:48.180] 对
# [26:48.180 --> 26:49.180] 那拉起来
# [26:49.180 --> 26:50.180] 绝对不可能说
# [26:50.180 --> 26:51.180] 每天都从台北看天下
# [26:51.180 --> 26:52.180] 对啊
# [26:52.180 --> 26:53.180] 对
# [26:53.180 --> 26:54.180] 那怎么样能够让他快
# [26:54.180 --> 26:55.180] 是
# [26:55.180 --> 26:56.180] 然后又有效
# [26:56.180 --> 26:57.180] 是
# [26:57.180 --> 26:58.180] 但最近大家都在谈
# [26:58.180 --> 26:59.180] 就是怎么建立
# [26:59.180 --> 27:00.180] 还怎么
# [27:00.180 --> 27:01.180] 因为
# [27:01.180 --> 27:02.180] 这个
# [27:02.180 --> 27:03.180] 孩子们
# [27:03.180 --> 27:06.180] 因为这孩子们已经是在AI的世代
# [27:06.180 --> 27:07.180] 让他要有
# [27:07.180 --> 27:11.180] 有点像AI的DNA
# [27:11.180 --> 27:13.180] 那我觉得从小就要让孩子
# [27:13.180 --> 27:15.180] 觉得说AI在他的身边
# [27:15.180 --> 27:16.180] 所以前一阵子不是说
# [27:16.180 --> 27:19.180] 大家要慢慢习惯你身边有很多机器人
# [27:19.180 --> 27:21.180] 甚至有的甚至说你要慢慢习惯
# [27:21.180 --> 27:24.180] 机器人比人类还多的世界
# [27:24.180 --> 27:26.180] 但那还早
# [27:26.180 --> 27:29.180] 不过我觉得说AI的融入生活
# [27:29.180 --> 27:30.180] 已经是一个
# [27:30.180 --> 27:31.180] 必然
# [27:31.180 --> 27:32.180] 对
# [27:32.180 --> 27:35.180] 那怎么样培养学生的这个叫AI的
# [27:35.180 --> 27:37.180] 不管是经验
# [27:37.180 --> 27:40.180] 我觉得我们这个平台就AI Maker
# [27:40.180 --> 27:42.180] 就是培养学生生成式AI
# [27:42.180 --> 27:44.180] 然后视觉听觉
# [27:44.180 --> 27:46.180] 这个可能涵盖一部分
# [27:46.180 --> 27:49.180] 在他的生活环境里面的一个
# [27:49.180 --> 27:51.180] 算一个经验
# [27:51.180 --> 27:53.180] 我觉得说如果这样可以
# [27:53.180 --> 27:55.180] 其实我因为在这边南部
# [27:55.180 --> 27:56.180] 因为科大
# [27:56.180 --> 27:58.180] 科大我招的学生是
# [27:58.180 --> 27:59.180] 是高职
# [27:59.180 --> 28:00.180] 为主
# [28:00.180 --> 28:01.180] 高中
# [28:01.180 --> 28:02.180] 也来可以来念
# [28:02.180 --> 28:03.180] 可是高中来念
# [28:03.180 --> 28:08.180] 我们的名额一般都是学校学生的名额的十分之一
# [28:08.180 --> 28:10.180] 所以高中来的本来就比较少
# [28:10.180 --> 28:13.180] 而且高中大部分念就一般大学
# [28:13.180 --> 28:14.180] 高职比较多
# [28:14.180 --> 28:18.180] 高职我们现在就跟台湾的附近台南
# [28:18.180 --> 28:21.180] 我现在台南嘉义云林台中
# [28:21.180 --> 28:24.180] 很多高职就加入我们的联盟
# [28:24.180 --> 28:26.180] 加入联盟之后
# [28:26.180 --> 28:28.180] 我就是要训练他们的老师
# [28:28.180 --> 28:30.180] 跟孩子玩这个
# [28:30.180 --> 28:33.180] 玩这个去结合
# [28:33.180 --> 28:35.180] 就那个产业
# [28:35.180 --> 28:36.180] 像我最近在推运的就是
# [28:36.180 --> 28:40.180] 我去帮云林口湖湖乡
# [28:40.180 --> 28:41.180] 湖乡比较漂亮
# [28:41.180 --> 28:42.180] 石丹云
# [28:42.180 --> 28:43.180] 对那边也种很多
# [28:43.180 --> 28:44.180] 养很多石吧
# [28:44.180 --> 28:46.180] 但是也养了很多蛤蜊
# [28:46.180 --> 28:47.180] 蛤蜊
# [28:47.180 --> 28:49.180] 蛤蜊要做分级
# [28:49.180 --> 28:50.180] 对
# [28:50.180 --> 28:51.180] 要刮刮刮这样子
# [28:51.180 --> 28:53.180] 那个是非常传统
# [28:53.180 --> 28:55.180] 我现在就带了学生
# [28:55.180 --> 28:57.180] 现在可能要带高职
# [28:57.180 --> 28:59.180] 土库工商
# [28:59.180 --> 29:01.180] 一起去
# [29:01.180 --> 29:03.180] 当然我已经在动了
# [29:03.180 --> 29:05.180] 就收集那些蛤蜊的质量
# [29:05.180 --> 29:06.180] 做分级
# [29:06.180 --> 29:07.180] 蛤蜊本身
# [29:07.180 --> 29:09.180] 第一个要判断它的好坏死活
# [29:09.180 --> 29:11.180] 是靠声音
# [29:11.180 --> 29:13.180] 对
# [29:13.180 --> 29:14.180] 所以我在设计一个就是
# [29:14.180 --> 29:16.180] 比较全自动的生产线
# [29:16.180 --> 29:18.180] 就是高速的那个输送带
# [29:18.180 --> 29:20.180] 然后让蛤蜊下坠
# [29:20.180 --> 29:21.180] 下坠为一个板子
# [29:21.180 --> 29:24.180] 直接这样子
# [29:24.180 --> 29:25.180] 直接就这边
# [29:25.180 --> 29:26.180] 活的继续走
# [29:26.180 --> 29:27.180] 死的就掉了
# [29:27.180 --> 29:29.180] 然后活的继续还要分
# [29:29.180 --> 29:30.180] 分级
# [29:30.180 --> 29:31.180] 对
# [29:31.180 --> 29:32.180] 级级
# [29:32.180 --> 29:33.180] 厚度
# [29:33.180 --> 29:35.180] 就让它全部都自动
# [29:35.180 --> 29:36.180] 那好啊
# [29:36.180 --> 29:38.180] 这个其实是帮产业
# [29:38.180 --> 29:40.180] 但是我要培养人才
# [29:40.180 --> 29:42.180] 因为我带学生进来
# [29:42.180 --> 29:44.180] 大学生高中生进来
# [29:44.180 --> 29:46.180] 让他们有成就感
# [29:46.180 --> 29:48.180] 你不只学AI
# [29:48.180 --> 29:49.180] 你还解决产地
# [29:49.180 --> 29:51.180] 当地这个产业
# [29:51.180 --> 29:52.180] 像
# [29:52.180 --> 29:54.180] 不管是农业
# [29:54.180 --> 29:55.180] 渔业
# [29:55.180 --> 29:56.180] 养殖业
# [29:56.180 --> 29:57.180] 畜牧业
# [29:57.180 --> 29:58.180] 其实都很需要AI
# [29:58.180 --> 29:59.180] 是的
# [29:59.180 --> 30:00.180] 你自己想自动化
# [30:00.180 --> 30:01.180] 你机机所备
# [30:01.180 --> 30:02.180] 你要导入
# [30:02.180 --> 30:04.180] 那一定要有好的视觉
# [30:04.180 --> 30:05.180] 所以我刚才讲
# [30:05.180 --> 30:07.180] 我们在开那个班的时候
# [30:07.180 --> 30:08.180] 我可以说
# [30:08.180 --> 30:09.180] 那我训练班
# [30:09.180 --> 30:11.180] 我今天全部找五金的
# [30:11.180 --> 30:13.180] 我们今天玩的都是五金
# [30:13.180 --> 30:14.180] 对
# [30:14.180 --> 30:16.180] 比如说我今天找一个行业
# [30:16.180 --> 30:18.180] 那我就找比如说一些
# [30:18.180 --> 30:20.180] 那我们今天就来玩
# [30:20.180 --> 30:21.180] 那个行业
# [30:21.180 --> 30:23.180] 我们也是希望这样
# [30:23.180 --> 30:24.180] 它的Domino就可以进来
# [30:24.180 --> 30:25.180] 对我们也是希望这样
# [30:25.180 --> 30:26.180] 就是说
# [30:26.180 --> 30:28.180] 尽可能这一个族群
# [30:28.180 --> 30:29.180] 对
# [30:29.180 --> 30:31.180] 就是说这个都是做五金扣件的
# [30:31.180 --> 30:32.180] 对
# [30:32.180 --> 30:34.180] 然后这个可能就是做养殖鱼的
# [30:34.180 --> 30:35.180] 对一般一般一般
# [30:35.180 --> 30:39.180] 因为你一定要大概都同行
# [30:39.180 --> 30:40.180] 如果虽然听声音
# [30:40.180 --> 30:41.180] 但是如果不同行
# [30:41.180 --> 30:42.180] 我们也很难教
# [30:42.180 --> 30:43.180] 是啊
# [30:43.180 --> 30:45.180] 因为完全不一样的东西
# [30:45.180 --> 30:47.180] 所以就可以说把属性相关
# [30:47.180 --> 30:48.180] 对
# [30:48.180 --> 30:49.180] 类似的
# [30:49.180 --> 30:50.180] 就集合起来
# [30:50.180 --> 30:51.180] 是
# [30:51.180 --> 30:52.180] 我们来开办培训
# [30:52.180 --> 30:53.180] 是
# [30:53.180 --> 30:55.180] 我刚才提到那个传统草原的钟晓维
# [30:55.180 --> 30:56.180] 他为什么不导入AI
# [30:56.180 --> 30:57.180] 因为他不知道什么叫AI
# [30:57.180 --> 30:58.180] 嗯嗯嗯
# [30:58.180 --> 31:00.180] 公司里面没有人懂怎么会导入
# [31:00.180 --> 31:01.180] 没错
# [31:01.180 --> 31:04.180] 你教一两个人来玩一下
# [31:04.180 --> 31:05.180] 他懂了
# [31:05.180 --> 31:06.180] 两个人走一指
# [31:06.180 --> 31:07.180] 对他回去才会弄嘛
# [31:07.180 --> 31:08.180] 对他不怕嘛
# [31:08.180 --> 31:09.180] 对
# [31:09.180 --> 31:10.180] 他觉得其实也没那么难
# [31:10.180 --> 31:11.180] 对
# [31:11.180 --> 31:12.180] 跟上面的老板沟通沟通
# [31:12.180 --> 31:14.180] 可能就开始导入
# [31:14.180 --> 31:15.180] 嗯嗯嗯
# [31:15.180 --> 31:17.180] 所以我觉得我们是在培养那个苗
# [31:17.180 --> 31:18.180] 是是是
# [31:18.180 --> 31:19.180] 培养那个苗
# [31:19.180 --> 31:21.180] 自己说真的要导入要很精密的
# [31:21.180 --> 31:23.180] 那就是专家来辅导
# [31:23.180 --> 31:24.180] 嗯嗯嗯嗯
# [31:24.180 --> 31:25.180] 专家来辅导
# [31:25.180 --> 31:26.180] 对对
# [31:26.180 --> 31:29.180] 所以我觉得我们这个平台就是来培养那个苗啦
# [31:29.180 --> 31:34.180] 然后让大家对这个叫AI的这种模型的建制
# [31:34.180 --> 31:35.180] 不要那么的
# [31:35.180 --> 31:37.180] 等于说不要那么害怕
# [31:37.180 --> 31:38.180] 对
# [31:38.180 --> 31:39.180] 那我可以请教一下下长吗
# [31:39.180 --> 31:41.180] 就是说以现在来说
# [31:41.180 --> 31:42.180] 我是不是可以说
# [31:42.180 --> 31:45.180] 南台在这个地方已经算是走的
# [31:45.180 --> 31:46.180] 算最前面
# [31:46.180 --> 31:47.180] 是的
# [31:47.180 --> 31:48.180] 太好了
# [31:48.180 --> 31:49.180] 而且就是说
# [31:49.180 --> 31:50.180] 我们是
# [31:50.180 --> 31:51.180] 我在这边
# [31:51.180 --> 31:55.180] 我在这边上任是四个月有二十五天
# [31:55.180 --> 31:56.180] 很巧
# [31:56.180 --> 31:57.180] 就是今天几月几号
# [31:57.180 --> 31:58.180] 我就是几月几号
# [31:58.180 --> 31:59.180] 哦真的
# [31:59.180 --> 32:00.180] 今天四月二十一天
# [32:00.180 --> 32:01.180] 对对对
# [32:01.180 --> 32:02.180] 我就是上任四月二十一天
# [32:02.180 --> 32:03.180] 啊
# [32:03.180 --> 32:05.180] 可是我这个AI Maker不是今天才做的
# [32:05.180 --> 32:06.180] 啊对对对
# [32:06.180 --> 32:08.180] 我是三年两三年前我就开始做
# [32:08.180 --> 32:09.180] 是是是
# [32:09.180 --> 32:10.180] 因为我农业已经做十年
# [32:10.180 --> 32:11.180] 是对对对
# [32:11.180 --> 32:13.180] 所以我知道我两三年前我就在想说
# [32:13.180 --> 32:15.180] 我要把它用来培养人才
# [32:15.180 --> 32:16.180] 对对
# [32:16.180 --> 32:18.180] 所以那时候这叫做玩农业学AI嘛
# [32:18.180 --> 32:19.180] 啊
# [32:19.180 --> 32:22.180] 所以就是视觉听觉我都已经在布啦
# [32:22.180 --> 32:23.180] 对
# [32:23.180 --> 32:24.180] 刚好来这边我就把它带来
# [32:24.180 --> 32:25.180] 太好了
